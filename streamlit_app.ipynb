# %%
# Le % pour être sûr de l'exécuter dans le bon dossier
# %notebook streamlit_app.ipynb 

# La commande pour lancer Streamlit depuis le notebook
# !jupyter nbconvert --to script app.ipynb # Si tu convertissais ton notebook en .py à la volée
# !streamlit run app.py
