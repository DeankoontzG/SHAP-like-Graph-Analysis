# %%
from utils_gene import *
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
G_name = "reel_jazz_collab_w_attributes.joblib"
path = f"../../graph_library/{G_name}"
print(f"Taille du fichier : {os.path.getsize(path)} octets")

G = joblib.load(path)
print(f"Graphe initial : Nodes : {G.number_of_nodes()}, Edges : {G.number_of_edges()}")

e_rs, k, commus = get_real_graph_properties_sbm_V2(G)
P_sbm = get_probs_sbm_non_DC(e_rs, commus)
#P_sbm = get_probs_sbm_DC(e_rs, k , commus)

degrees, position = get_real_graph_properties_pos_V2(G)
sigma_opt, P_spatial_calibrated = match_spatial_to_sbm_variance(P_sbm, degrees, position, DC=False)
P_spatial = get_probs_spatial_non_DC(position, n_liens_target= G.number_of_edges(), sigma = sigma_opt)
#P_spatial, degrees = get_probs_spatial_DC(degrees, position, sigma = sigma_opt)

g_sbm = generate_graph_from_probs(P_sbm)
g_spatial = generate_graph_from_probs(P_spatial)
g_spatial_nx = convert_to_nx_with_metadata(g_spatial, position, k, degrees, commus, e_rs)
g_sbm_nx = convert_to_nx_with_metadata(g_sbm, position, k, degrees, commus, e_rs, P_sbm)


print(f"P_SBM : {P_sbm[2][3]}")
print(f"P_SBM : {P_sbm[3][2]}")

nu = g_spatial_nx.nodes[0]
print(f"DEBUG: Attr cherché: | Présents dans nu: {list(nu.keys())}")

print(f"SBM VS spatial = {g_sbm.num_edges()} VS {g_spatial.num_edges()}")

entropy_sbm = get_entropy_from_p(P_sbm)
log_likelyhood_sbm = get_log_likelihood(g_sbm, P_sbm)
entropy_spatial = get_entropy_from_p(P_spatial)
log_likelyhood_spatial = get_log_likelihood(g_spatial, P_spatial)
var_sbm = get_variance_from_P(P_sbm)
var_spatial = get_variance_from_P(P_spatial)

print(f" Entropy VS Log_likelyhood SBM : {entropy_sbm} / {log_likelyhood_sbm}")
print(f" Entropy VS Log_likelyhood Spatial : {entropy_spatial} / {log_likelyhood_spatial}")
print(f" Variance SBM VS Spatial : {var_sbm} / {var_spatial}")

plot_degree_correlation(k, g_sbm, g_spatial)
#visualize_generation_diagnostics_v2(P_sbm, P_spatial, k, e_rs, b)

analyze_errors(g_spatial, P_spatial)
analyze_errors(g_sbm, P_sbm)
# Out:
# Taille du fichier : 182851 octets
# Graphe initial : Nodes : 198, Edges : 2742
# Variance cible (SBM) : 0.04838831
# ------------------------------
#  Alpha trouvé : 3.5734 pour 2742.0 liens visés.
# Step 01 | Sigma testé: 19.1014 | Var: 0.07397459 | Δ: 2.56e-02
#  Alpha trouvé : 5.8435 pour 2742.0 liens visés.
# Step 02 | Sigma testé: 30.9036 | Var: 0.09026740 | Δ: 4.19e-02
#  Alpha trouvé : 2.0446 pour 2742.0 liens visés.
# Step 03 | Sigma testé: 11.8072 | Var: 0.05342612 | Δ: 5.04e-03
#  Alpha trouvé : 0.9173 pour 2742.0 liens visés.
# Step 04 | Sigma testé: 7.2992 | Var: 0.03153702 | Δ: 1.69e-02
#  Alpha trouvé : 2.0679 pour 2742.0 liens visés.
# Step 05 | Sigma testé: 11.9099 | Var: 0.05382468 | Δ: 5.44e-03
#  Alpha trouvé : 1.8355 pour 2742.0 liens visés.
# Step 06 | Sigma testé: 10.9021 | Var: 0.04972889 | Δ: 1.34e-03
#  Alpha trouvé : 1.5034 pour 2742.0 liens visés.
# Step 07 | Sigma testé: 9.5259 | Var: 0.04343891 | Δ: 4.95e-03
#  Alpha trouvé : 1.7775 pour 2742.0 liens visés.
# Step 08 | Sigma testé: 10.6562 | Var: 0.04866545 | Δ: 2.77e-04
#  Alpha trouvé : 1.7668 pour 2742.0 liens visés.
# Step 09 | Sigma testé: 10.6109 | Var: 0.04846660 | Δ: 7.83e-05
#  Alpha trouvé : 1.7623 pour 2742.0 liens visés.
# Step 10 | Sigma testé: 10.5918 | Var: 0.04838255 | Δ: 5.76e-06
#  Alpha trouvé : 1.7626 pour 2742.0 liens visés.
# Step 11 | Sigma testé: 10.5930 | Var: 0.04838809 | Δ: 2.21e-07
#  Alpha trouvé : 1.7626 pour 2742.0 liens visés.
# Step 12 | Sigma testé: 10.5931 | Var: 0.04838832 | Δ: 5.21e-09
#  Alpha trouvé : 1.7626 pour 2742.0 liens visés.
# Step 13 | Sigma testé: 10.5931 | Var: 0.04838830 | Δ: 1.02e-08
#  Alpha trouvé : 1.7626 pour 2742.0 liens visés.
# Step 14 | Sigma testé: 10.5931 | Var: 0.04838833 | Δ: 2.06e-08
# ------------------------------
#  Alpha trouvé : 1.7626 pour 2742.0 liens visés.
# ✨ Sigma optimal trouvé : 10.5931
# 📊 Variance finale Spatial : 0.04838832 (Écart: 5.21e-09)
#  Alpha trouvé : 1.7626 pour 2742 liens visés.
# P_SBM : 0.09126984126984126
# P_SBM : 0.09126984126984126
# DEBUG: Attr cherché: | Présents dans nu: []
# SBM VS spatial = 2676 VS 2716
#  Entropy VS Log_likelyhood SBM : 6456.188886100566 / -6346.095505234369
#  Entropy VS Log_likelyhood Spatial : 6521.472306591515 / -6576.527871284512
#  Variance SBM VS Spatial : 0.048388310158659305 / 0.04838831536608761
# Erreur Moyenne Absolue (MAE) SBM     : 9.49
# Erreur Moyenne Absolue (MAE) Spatial : 16.60
# Proba moyenne pour les arêtes réelles : 0.482182
# Proba min pour une arête réelle : 0.001750615716
# Nombre d'arêtes 'impossibles' selon le modèle : 0
# Proba moyenne pour les arêtes réelles : 0.489291
# Proba min pour une arête réelle : 0.002557544757
# Nombre d'arêtes 'impossibles' selon le modèle : 0

# %%
Hybrid_ratios_list = np.arange(0.42, 0.62, 0.02)

for nb_iter in range(1,31) : 
    nb_iter_name = f"_{nb_iter}"
    all_P_matrices = generate_graph_benchmarks(Hybrid_ratios_list, P_sbm, P_spatial, position, k, degrees, commus, 
                          e_rs, name="artificial_graph_sbmv4", save_P_matrix=True, nb_iter = nb_iter_name)

    # --- Aperçu de l'objet all_P_matrices ---
    print("\n" + "="*90)
    print("🔍 APERÇU DU DICTIONNAIRE DE MATRICES (all_P_matrices)")
    print("="*90)
    print(f"Nombre de matrices stockées : {len(all_P_matrices)}")
    print(f"Ratios disponibles (clés)  : {list(all_P_matrices.keys())}")
    
    # Print de quelques valeurs pour tester l'accès [u, v]
    # On prend le premier alpha et on affiche un coin 3x3 de la matrice
    first_alpha = list(all_P_matrices.keys())[0]
    print(f"\nExtrait de la matrice pour alpha = {first_alpha} (nœuds 0 à 2) :")
    print(all_P_matrices[first_alpha][:3, :3]) 
    print("="*90)
# Out:
# ==========================================================================================
# Pour ratio_sbm = 0.42
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_42_pos_0_58
graphml
#
# ==========================================================================================
# 📊 TABLEAU RÉCAPITULATIF DE L'HYBRIDATION
# ==========================================================================================
#              Modèle    N     E    Variance  Entropy Log-Likelihood Clustering
# 0  Hybride (α=0.42)  198  2676  0.02524491  8560.65       -8454.56     0.2278
# 1  Hybride (α=0.44)  198  2731  0.02497889  8580.42       -8540.50     0.2285
# 2  Hybride (α=0.46)  198  2765  0.02478888  8594.59       -8588.95     0.2342
# 3  Hybride (α=0.48)  198  2793  0.02467487  8603.17       -8678.98     0.2272
# 4  Hybride (α=0.50)  198  2765  0.02463687  8606.19       -8562.18     0.2313
# 5  Hybride (α=0.52)  198  2830  0.02467487  8603.64       -8713.70     0.2334
# 6  Hybride (α=0.54)  198  2771  0.02478888  8595.51       -8642.85     0.2286
# 7  Hybride (α=0.56)  198  2757  0.02497889  8581.78       -8759.77     0.2237
# 8  Hybride (α=0.58)  198  2721  0.02524491  8562.41       -8531.43     0.2263
# 9  Hybride (α=0.60)  198  2733  0.02558693  8537.36       -8620.66     0.2237
# ==========================================================================================
#  Dataset de matrices sauvegardé avec succès : ../../graph_library/artificial_graph_sbmv4_P_matrices.joblib
# Taille du fichier : 3.14 MB
#
# ==========================================================================================
# 🔍 APERÇU DU DICTIONNAIRE DE MATRICES (all_P_matrices)
# ==========================================================================================
# Nombre de matrices stockées : 10
# Ratios disponibles (clés)  : [0.42, 0.44, 0.46, 0.48, 0.5, 0.52, 0.54, 0.56, 0.58, 0.6]
#
# Extrait de la matrice pour alpha = 0.42 (nœuds 0 à 2) :
# [[0.         0.16311822 0.1765708 ]
#  [0.16311822 0.         0.16261358]
#  [0.1765708  0.16261358 0.        ]]
# ==========================================================================================
#
# ==========================================================================================
# Pour ratio_sbm = 0.42
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_42_pos_0_58_30.graphml
#
# ==========================================================================================
# Pour ratio_sbm = 0.44
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_44_pos_0_56_30.graphml
#
# ==========================================================================================
# Pour ratio_sbm = 0.46
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_46_pos_0_54_30.graphml
#
# ==========================================================================================
# Pour ratio_sbm = 0.48000000000000004
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_48_pos_0_52_30.graphml
#
# ==========================================================================================
# Pour ratio_sbm = 0.5
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_50_pos_0_50_30.graphml
#
# ==========================================================================================
# Pour ratio_sbm = 0.52
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_52_pos_0_48_30.graphml
#
# ==========================================================================================
# Pour ratio_sbm = 0.54
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_54_pos_0_46_30.graphml
#
# ==========================================================================================
# Pour ratio_sbm = 0.56
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_56_pos_0_44_30.graphml
#
# ==========================================================================================
# Pour ratio_sbm = 0.5800000000000001
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_58_pos_0_42_30.graphml
#
# ==========================================================================================
# Pour ratio_sbm = 0.6000000000000001
#
# ==========================================================================================
# Graphe exporté avec succès dans : ../../graph_library/artificial_graph_sbmv4_0_60_pos_0_40_30.graphml
#
# ==========================================================================================
# 📊 TABLEAU RÉCAPITULATIF DE L'HYBRIDATION
# ==========================================================================================
#              Modèle    N     E    Variance  Entropy Log-Likelihood Clustering
# 0  Hybride (α=0.42)  198  2807  0.02524491  8560.65       -8627.12     0.2389
# 1  Hybride (α=0.44)  198  2688  0.02497889  8580.42       -8474.80     0.2298
# 2  Hybride (α=0.46)  198  2635  0.02478888  8594.59       -8486.06     0.2167
# 3  Hybride (α=0.48)  198  2734  0.02467487  8603.17       -8545.61     0.2272
# 4  Hybride (α=0.50)  198  2749  0.02463687  8606.19       -8682.98     0.2182
# 5  Hybride (α=0.52)  198  2703  0.02467487  8603.64       -8644.79     0.2170
# 6  Hybride (α=0.54)  198  2778  0.02478888  8595.51       -8722.71     0.2210
# 7  Hybride (α=0.56)  198  2779  0.02497889  8581.78       -8625.24     0.2296
# 8  Hybride (α=0.58)  198  2702  0.02524491  8562.41       -8579.67     0.2277
# 9  Hybride (α=0.60)  198  2741  0.02558693  8537.36       -8507.30     0.2325
# ==========================================================================================
#  Dataset de matrices sauvegardé avec succès : ../../graph_library/artificial_graph_sbmv4_P_matrices.joblib
# Taille du fichier : 3.14 MB
#
# ==========================================================================================
# 🔍 APERÇU DU DICTIONNAIRE DE MATRICES (all_P_matrices)
# ==========================================================================================
# Nombre de matrices stockées : 10
# Ratios disponibles (clés)  : [0.42, 0.44, 0.46, 0.48, 0.5, 0.52, 0.54, 0.56, 0.58, 0.6]
#
# Extrait de la matrice pour alpha = 0.42 (nœuds 0 à 2) :
# [[0.         0.16311822 0.1765708 ]
#  [0.16311822 0.         0.16261358]
#  [0.1765708  0.16261358 0.        ]]
# ==========================================================================================

# %%
G = load_graphml_safe("../../graph_library/artificial_graph_sbmv5_1_00_pos_0_00.graphml")
plot_sbm_density_comparison(G)
# Out:
# Graphe chargé : 198 nœuds et 2601 liens.
# Erreur : L'attribut 'GT_true_probs' est introuvable.
